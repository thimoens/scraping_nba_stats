# %%
# Import libraries
import numpy as np
import pandas as pd
import requests
import time

# See all the columns in wide dataframe
pd.set_option('display.max_columns', None)

# %%
# Get a nice API url from nba.com
test_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=Totals'
